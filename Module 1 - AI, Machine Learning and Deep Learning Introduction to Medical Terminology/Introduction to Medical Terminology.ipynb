# %% [markdown]
# # Module 1 - AI, Machine Learning and Deep Learning: Introduction to Medical Terminology
#
# This notebook accompanies the Module 1 written assignment. The assignment involved
# researching ten medical terms sourced from current peer-reviewed clinical literature.
# Each term was defined, placed in research context, and evaluated for its significance
# to patient outcomes. This notebook organizes those terms and demonstrates how
# structured data can be built from qualitative medical research.

# %% [markdown]
# ## Setting Up
# We will use pandas to load and display the terminology data as a structured table.

# %%
import pandas as pd

# %% [markdown]
# ## Building the Medical Terminology Dataset
# Each term from the assignment is entered with its definition, clinical context,
# and area of medicine it belongs to.

# %%
data = {
    "Term": [
        "Delayed Cerebral Ischemia",
        "Sacituzumab Govitecan",
        "Tobevibart",
        "Erythematous Papules",
        "Atrial Fibrillation",
        "Efgartigimod",
        "Ductal Carcinoma",
        "Opacities",
        "Fremanezumab",
        "Hemolytic"
    ],
    "Medical Area": [
        "Neurology",
        "Oncology",
        "Hepatology",
        "Dermatology",
        "Cardiology",
        "Immunology",
        "Oncology",
        "Pulmonology",
        "Neurology",
        "Hematology"
    ],
    "Type": [
        "Condition",
        "Drug",
        "Drug",
        "Symptom",
        "Condition",
        "Drug",
        "Condition",
        "Imaging Finding",
        "Drug",
        "Process"
    ],
    "Clinical Significance": [
        "Causes death or disability in up to 30% of SAH survivors",
        "Targets TROP2 protein in treatment-resistant breast cancer",
        "Demonstrated sustained viral suppression in hepatitis D over 48 weeks",
        "Visible markers guiding diagnosis of skin and systemic conditions",
        "Most common sustained cardiac arrhythmia linked to stroke risk",
        "Prevents maternal antibodies from crossing placenta in high-risk pregnancies",
        "Accounts for 80% of breast cancer diagnoses",
        "Radiographic markers guiding pulmonary diagnosis and treatment",
        "Proven reduction in migraine days in children and adolescents",
        "Red blood cell breakdown central to autoimmune anemia management"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                         Term Medical Area             Type  \
# 0  Delayed Cerebral Ischemia    Neurology        Condition
# 1      Sacituzumab Govitecan     Oncology             Drug
# 2                 Tobevibart   Hepatology             Drug
# 3       Erythematous Papules  Dermatology          Symptom
# 4        Atrial Fibrillation   Cardiology        Condition
# 5               Efgartigimod   Immunology             Drug
# 6           Ductal Carcinoma     Oncology        Condition
# 7                  Opacities  Pulmonology  Imaging Finding
# 8               Fremanezumab    Neurology             Drug
# 9                  Hemolytic   Hematology          Process
#
#                                Clinical Significance
# 0  Causes death or disability in up to 30% of SAH...
# 1  Targets TROP2 protein in treatment-resistant b...
# 2  Demonstrated sustained viral suppression in he...
# 3  Visible markers guiding diagnosis of skin and ...
# ...

# %% [markdown]
# ## Summary Statistics
# A quick breakdown of how the terms distribute across medical areas and term types.

# %%
print("Total Terms Researched:", len(df))
print("\nTerms by Medical Area:")
print(df["Medical Area"].value_counts())
print("\nTerms by Type:")
print(df["Type"].value_counts())
# Out:
# Total Terms Researched: 10
#
# Terms by Medical Area:
# Medical Area
# Neurology      2
# Oncology       2
# Hepatology     1
# Dermatology    1
# Cardiology     1
# Immunology     1
# Pulmonology    1
# Hematology     1
# Name: count, dtype: int64
#
# Terms by Type:
# Type
# Drug               4
# Condition          3
# Symptom            1
# Imaging Finding    1
# Process            1
# Name: count, dtype: int64

# %% [markdown]
# ## Takeaway
# Organizing medical terminology into structured data is itself an AI-relevant skill.
# Clinical NLP models, diagnostic classifiers, and CDSS tools all depend on clean,
# labeled data as a foundation. This exercise reflects how unstructured research
# gets converted into something a system can process and learn from.
