# %% [markdown]
# # Module 4 - AI-Based Diagnostic Tools
#
# This notebook accompanies the Module 4 written assignment, which evaluated the
# Determine™ HIV Early Detect test in a real-world clinical deployment across rural
# Eswatini. The focus was on how the test performed against its core objective of
# detecting acute HIV infection and what that revealed about translating lab results
# into field performance.

# %% [markdown]
# ## Installing and Importing Libraries

# %%
# !pip install pandas matplotlib --quiet
import pandas as pd
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Test Performance Metrics
# The study reported three key diagnostic metrics for the Determine™ HIV Early Detect test.

# %%
metrics = {
    "Metric": ["Specificity", "Overall HIV Sensitivity", "Acute HIV Sensitivity"],
    "Value (%)": [99.8, 83.7, 20.0]
}

df = pd.DataFrame(metrics)
print(df.to_string(index=False))
# Out:
#                  Metric  Value (%)
#             Specificity       99.8
# Overall HIV Sensitivity       83.7
#   Acute HIV Sensitivity       20.0

# %% [markdown]
# ## Takeaway
# The 20% sensitivity for acute HIV infection exposes a critical gap between
# laboratory promise and field performance. A near-perfect specificity means
# negative results are reliable, but the test largely fails at its primary objective
# of catching HIV during the window when transmission risk is highest.
