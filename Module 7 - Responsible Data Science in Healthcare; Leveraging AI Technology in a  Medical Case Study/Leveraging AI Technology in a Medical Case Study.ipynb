# %% [markdown]
# # Module 7 - Responsible Data Science in Healthcare: Leveraging AI Technology in a Medical Case Study
#
# This notebook accompanies the Module 7 written assignment, which analyzed a
# 42-year-old male patient with concurrent Graves' disease and rheumatoid arthritis
# and examined how AI tools could manage the risks his case presented.

# %% [markdown]
# ## Installing and Importing Libraries

# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# ## Patient Risk Summary
# The three primary risks identified in the case and their contributing factors.

# %%
risks = {
    "Risk": [
        "Compounded Autoimmune Progression",
        "Smoking as Disease Accelerant",
        "Drug Interaction and Treatment Imbalance"
    ],
    "Contributing Factor": [
        "Bidirectional relationship between Graves disease and RA",
        "30-year smoking history amplifying systemic inflammation",
        "Methotrexate and Prednisolone interfering with thyroid hormone levels"
    ],
    "AI Application": [
        "Continuous patient-reported outcome monitoring between appointments",
        "Behavioral tracking and cessation support prompts",
        "Real-time hormone fluctuation alerts for the care team"
    ]
}

df = pd.DataFrame(risks)
df
# Out:
#                                        Risk  \
# 0         Compounded Autoimmune Progression
# 1             Smoking as Disease Accelerant
# 2  Drug Interaction and Treatment Imbalance
#
#                                  Contributing Factor  \
# 0  Bidirectional relationship between Graves dise...
# 1  30-year smoking history amplifying systemic in...
# 2  Methotrexate and Prednisolone interfering with...
#
#                                       AI Application
# 0  Continuous patient-reported outcome monitoring...
# 1  Behavioral tracking and cessation support prompts
# 2  Real-time hormone fluctuation alerts for the c...

# %% [markdown]
# ## Takeaway
# Responsible AI in this context is not about automation. It is about closing the
# gaps that standard care delivery cannot cover, continuous monitoring, real-time
# drug interaction tracking, and cross-specialty data coordination.
