# %% [markdown]
# # Module 8 - Natural Language Processing in Healthcare: Critiquing NLP
#
# This notebook accompanies the Module 8 written assignment, which examined how
# NLP extracts clinically relevant information from unstructured medical text and
# the privacy infrastructure required to do that responsibly.

# %% [markdown]
# ## Installing and Importing Libraries

# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# ## NLP Pipeline Stages
# The stages clinical text moves through before a model is trained on it.

# %%
pipeline = {
    "Stage": ["Text Cleaning", "Segmentation", "Feature Extraction", "Model Training", "Evaluation"],
    "Description": [
        "Remove HTML tags, correct spelling, expand abbreviations",
        "Break text into meaningful clinical segments",
        "Identify relevant terms using keyword lists and Levenshtein distance",
        "Train ML model on extracted features",
        "Measure performance using F1 score and AUC"
    ]
}

df = pd.DataFrame(pipeline)
df
# Out:
#                 Stage                                        Description
# 0       Text Cleaning  Remove HTML tags, correct spelling, expand abb...
# 1        Segmentation       Break text into meaningful clinical segments
# 2  Feature Extraction  Identify relevant terms using keyword lists an...
# 3      Model Training               Train ML model on extracted features
# 4          Evaluation         Measure performance using F1 score and AUC

# %% [markdown]
# ## Takeaway
# NLP surfaces information that structured documentation consistently fails to capture.
# The pipeline only performs as well as the data going into it, and responsible
# deployment requires privacy infrastructure that matches the sensitivity of that data.
